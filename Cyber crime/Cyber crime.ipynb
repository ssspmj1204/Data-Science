# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
crime_data = pd.read_csv("경찰청_연도별 사이버범죄통계.csv", encoding = "euc-kr", index_col = "구분")
crime_data = crime_data.sort_index()
crime_data
# Out:
#       구분.1  해킹(계정도용)  해킹(단순침입)  해킹(자료유출)  해킹(자료훼손)  서비스거부공격  악성프로그램(랜섬웨어)  \
# 구분
# 2014  발생건수       567       760       116       205       26             0
# 2014  검거건수       130       226        81       103       16             0
# 2015  발생건수      1062       809        69       307       40             0
# 2015  검거건수       185       191        36       112       19             0
# 2016  발생건수       758       714        71       304      192             0
# 2016  검거건수       161       194        38       144      164             0
# 2017  발생건수      1160       904        67       299       43            11
# 2017  검거건수       619       219        36       116       28             1
# 2018  발생건수       721      1003       114       340       20            33
# 2018  검거건수       160       241        41       142       14             1
# 2019  발생건수       751      1458       114       341       35            24
# 2019  검거건수       118       277        41       120       14             0
#
#       악성프로그램(기타)  기타 정보통신망 침해형 범죄  인터넷사기(직거래)  ...  사이버 음란물(일반음란물)  \
# 구분                                             ...
# 2014           0              487       45877  ...            3633
# 2014           0              221       33502  ...            3046
# 2015           0              701       67861  ...            3523
# 2015           0              225       57605  ...            2801
# 2016           0              594       76228  ...            2515
# 2016           0              248       68922  ...            2237
# 2017         156              516       67589  ...            2043
# 2017         121              258       60502  ...            1794
# 2018          86              571       74044  ...            2661
# 2018          49              254       60224  ...            2250
# 2019         246              669       89797  ...            1769
# 2019         189              248       72935  ...            1436
#
#       사이버 음란물(아동성착취물)  사이버 음란물(불법촬영물유포)  사이버 도박(스포츠토토)  사이버 도박(경마·경륜·경정)  \
# 구분
# 2014              721                 0           2610               151
# 2014              693                 0           2510               147
# 2015              721                 0           2270               133
# 2015              674                 0           2242               128
# 2016             1262                 0           6227               296
# 2016             1198                 0           6141               295
# 2017              603                 0           3169               211
# 2017              535                 0           3127               205
# 2018             1172                 0           1629               276
# 2018             1032                 0           1599               257
# 2019              756               165           3078               366
# 2019              589               139           3017               352
#
#       사이버 도박(카지노)  사이버 도박(기타)  사이버 명예훼손·모욕  사이버 스토킹  기타 불법 컨텐츠
# 구분
# 2014            0        1510         8880      363        431
# 2014            0        1390         6241      300        316
# 2015           31         918        15043      134        390
# 2015           34         961        10202      124        222
# 2016          592        2423        14908       56        159
# 2016          583        2375        10539       53        118
# 2017          227        1523        13348       59        124
# 2017          228        1520         9756       52         95
# 2018          176         931        15926       60        208
# 2018          167         924        10889       50        137
# 2019          366        1536        16633       25        251
# 2019          353        1440        11632       20        176
#
# [12 rows x 34 columns]

# %%
occur = crime_data[crime_data['구분.1'] == "발생건수"]
occur = occur.T
occur.drop('구분.1', inplace = True)
occur.name = '발생'
occur
# Out:
# 구분                 2014   2015   2016   2017   2018   2019
# 해킹(계정도용)            567   1062    758   1160    721    751
# 해킹(단순침입)            760    809    714    904   1003   1458
# 해킹(자료유출)            116     69     71     67    114    114
# 해킹(자료훼손)            205    307    304    299    340    341
# 서비스거부공격              26     40    192     43     20     35
# 악성프로그램(랜섬웨어)          0      0      0     11     33     24
# 악성프로그램(기타)            0      0      0    156     86    246
# 기타 정보통신망 침해형 범죄     487    701    594    516    571    669
# 인터넷사기(직거래)        45877  67861  76228  67589  74044  89797
# 인터넷사기(쇼핑몰)         1672   2184   2149    560    647    960
# 인터넷사기(게임)          1700   2731   4555   7227   9380   7687
# 인터넷사기(이메일 무역사기)       0      0      0    187    367    305
# 인터넷사기(기타)          7418   9073  17437  17073  27562  37325
# 사이버금융범죄(피싱)        1962   1726    427    545   1978   2874
# 사이버금융범죄(파밍)        7101   9233   2817   1933    191     45
# 사이버금융범죄(스미싱)       4917   1120    562    667    293    207
# 사이버금융범죄(메모리해킹)      155    124     12     12     11     11
# 사이버금융범죄(몸캠피싱)         0    102   1193   1234   1406   1824
# 사이버금융범죄(메신저피싱)        0      0      0      0      0   2756
# 사이버금융범죄(기타)        1461   2381   1710   1675   1742   2825
# 개인위치정보 침해           939    609   2410    413    246    179
# 사이버저작권침해          14168  18770   9796   6667   3856   2562
# 기타 정보통신망 이용형 범죄    2149   2448   2571   1489   1954   2559
# 사이버 음란물(일반음란물)     3633   3523   2515   2043   2661   1769
# 사이버 음란물(아동성착취물)     721    721   1262    603   1172    756
# 사이버 음란물(불법촬영물유포)      0      0      0      0      0    165
# 사이버 도박(스포츠토토)      2610   2270   6227   3169   1629   3078
# 사이버 도박(경마·경륜·경정)    151    133    296    211    276    366
# 사이버 도박(카지노)           0     31    592    227    176    366
# 사이버 도박(기타)         1510    918   2423   1523    931   1536
# 사이버 명예훼손·모욕        8880  15043  14908  13348  15926  16633
# 사이버 스토킹             363    134     56     59     60     25
# 기타 불법 컨텐츠           431    390    159    124    208    251

# %%
arrest = crime_data[crime_data['구분.1'] == "검거건수"]
arrest = arrest.T
arrest.drop('구분.1', inplace = True)
arrest.name = '검거'
arrest
# Out:
# 구분                 2014   2015   2016   2017   2018   2019
# 해킹(계정도용)            130    185    161    619    160    118
# 해킹(단순침입)            226    191    194    219    241    277
# 해킹(자료유출)             81     36     38     36     41     41
# 해킹(자료훼손)            103    112    144    116    142    120
# 서비스거부공격              16     19    164     28     14     14
# 악성프로그램(랜섬웨어)          0      0      0      1      1      0
# 악성프로그램(기타)            0      0      0    121     49    189
# 기타 정보통신망 침해형 범죄     221    225    248    258    254    248
# 인터넷사기(직거래)        33502  57605  68922  60502  60224  72935
# 인터넷사기(쇼핑몰)         1352   1529   1966    476    526    793
# 인터넷사기(게임)          1244   2229   3804   6150   7545   6183
# 인터넷사기(이메일 무역사기)       0      0      0     19     29     23
# 인터넷사기(기타)          4559   7081  14672  13593  19390  25717
# 사이버금융범죄(피싱)        1239   1222    347    354    936    984
# 사이버금융범죄(파밍)        3961   5064   1756    946    100     39
# 사이버금융범죄(스미싱)        460    207    109     83    174     32
# 사이버금융범죄(메모리해킹)       71     59      7      6      5      3
# 사이버금융범죄(몸캠피싱)         0     38    880    334    281    478
# 사이버금융범죄(메신저피싱)        0      0      0      0      0    811
# 사이버금융범죄(기타)         836   1296    935    909    857   1040
# 개인위치정보 침해           635    296   2125    298    142     78
# 사이버저작권침해           7198   8832   5616   4134   2467   1772
# 기타 정보통신망 이용형 범죄    1404   1200   2033    975   1250   1510
# 사이버 음란물(일반음란물)     3046   2801   2237   1794   2250   1436
# 사이버 음란물(아동성착취물)     693    674   1198    535   1032    589
# 사이버 음란물(불법촬영물유포)      0      0      0      0      0    139
# 사이버 도박(스포츠토토)      2510   2242   6141   3127   1599   3017
# 사이버 도박(경마·경륜·경정)    147    128    295    205    257    352
# 사이버 도박(카지노)           0     34    583    228    167    353
# 사이버 도박(기타)         1390    961   2375   1520    924   1440
# 사이버 명예훼손·모욕        6241  10202  10539   9756  10889  11632
# 사이버 스토킹             300    124     53     52     50     20
# 기타 불법 컨텐츠           316    222    118     95    137    176

# %%
from matplotlib import font_manager,rc
rc('font', family = 'NanumGothic')

# %%
x = occur.iloc[0]
x_name = occur.iloc[0].name

# %%
plt.plot(x, label = occur.name)
plt.xlabel("발생연도")
plt.ylabel("발생건수")
plt.title(x_name)
plt.legend()
plt.show()

# %%
occur.shape
occur.iloc[32]
# Out:
# 구분
# 2014    431
# 2015    390
# 2016    159
# 2017    124
# 2018    208
# 2019    251
# Name: 기타 불법 컨텐츠, dtype: object

# %%
for i in range(33): 
    occur_num = occur.iloc[i]
    arrest_num = arrest.iloc[i]
    crime_name = occur.iloc[i].name
    plt.plot(x, label = occur.name, marker = 'o', color = 'b')
    plt.plot(y, label = arrest.name, marker = 'o', color = 'r')
    plt.xlabel("발생연도")
    plt.ylabel("건수")
    plt.title(crime_name)
    plt.legend()
    plt.show()
